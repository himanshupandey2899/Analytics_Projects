# %% [markdown]
# # Shopping Mall Customer Segmentation Analysis
#
# ## Business Analyst Internship Project
#
# ### Project Objective
# The objective of this project is to analyze customer demographics, annual income, and spending behavior to identify distinct customer segments.
#
# The insights generated will support business decision-making in:
# - Customer targeting
# - Marketing optimization
# - Customer retention strategies
# - Revenue growth initiatives

# %% [markdown]
# ## Business Problem Statement
#
# Retail businesses serve customers with diverse purchasing behaviors and income levels.
# Without proper segmentation, marketing campaigns become inefficient and fail to maximize customer value.
#
# This project aims to:
# - Understand customer characteristics
# - Analyze spending patterns
# - Identify meaningful customer segments
# - Provide actionable business recommendations

# %% [markdown]
# ## Analytical Approach
#
# The project will follow a structured Business Analytics workflow:
#
# 1. Data Understanding
# 2. Data Cleaning
# 3. Customer Analysis
# 4. Customer Segmentation
# 5. Visualization & Dashboard Development
# 6. Business Recommendations

# %% [markdown]
# ## Dataset Overview
#
# The dataset contains customer information collected from a shopping mall.
#
# ### Dataset Features
# - Customer ID: Unique identifier for each customer
# - Gender: Male or Female
# - Age: Customer age
# - Annual Income (k$): Customer yearly income
# - Spending Score (1–100): Indicator of purchasing behavior assigned by the mall

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Part 1: Data Cleaning & Understanding
#
# 1. Import the dataset.
# 2. Check for missing/null values.
# 3. Check data types and clean the dataset.

# %% [markdown]
# ## Step 1: Import Required Libraries
#
# The following libraries are imported to perform data manipulation, statistical analysis, and visualization.
#
# - Pandas → data handling
# - NumPy → numerical operations
# - Matplotlib & Seaborn → visualization

# %%
# Importing Required Libraries

# Data handling
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 2: Load the Dataset
#
# The dataset is loaded into a Pandas DataFrame to enable data exploration and preprocessing.

# %%
import os
print(os.getcwd())
print(os.path.exists("../01 Data/Shopping Mall Customer Segmentation Data .csv"))
# Out:
# C:\Users\himan\AppData\Local\Programs\Microsoft VS Code
# False

# %%
# Loading Dataset

df = pd.read_csv("../01 Data/Shopping Mall Customer Segmentation Data .csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 3
#       1 # Loading Dataset
# ----> 3 df = pd.read_csv("../01 Data/Shopping Mall Customer Segmentation Data .csv")
#
# File c:\Users\himan\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...

# %% [markdown]
# ## Step 3: Preview Dataset
#
# Displaying the first few records helps understand the structure, variables, and overall format of the dataset.

# %%
# Previewing Dataset

df.head(3)
# Out:
#                             Customer ID  Age  Gender  Annual Income  \
# 0  d410ea53-6661-42a9-ad3a-f554b05fd2a7   30    Male         151479
# 1  1770b26f-493f-46b6-837f-4237fb5a314e   58  Female         185088
# 2  e81aa8eb-1767-4b77-87ce-1620dc732c5e   62  Female          70912
#
#    Spending Score
# 0              89
# 1              95
# 2              76

# %% [markdown]
# ## Step 4: Dataset Dimensions
#
# Understanding dataset size provides clarity on the number of customers analyzed and available features.

# %%
# Understanding Dataset Size

df.shape
# Out:
# (15079, 5)

# %% [markdown]
# ## Step 5: Data Structure and Data Types
#
# This step identifies:
# - Numerical variables suitable for analysis
# - Categorical variables for segmentation
# - Potential data cleaning requirements

# %%
# Understanding Dataset Structure

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15079 entries, 0 to 15078
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer ID     15079 non-null  str
#  1   Age             15079 non-null  int64
#  2   Gender          15079 non-null  str
#  3   Annual Income   15079 non-null  int64
#  4   Spending Score  15079 non-null  int64
# dtypes: int64(3), str(2)
# memory usage: 589.2 KB

# %% [markdown]
# ## Step 6: Statistical Summary
#
# Descriptive statistics provide an overview of customer demographics, income distribution, and spending behavior.

# %%
# Numerical Summary

df.describe()
# Out:
#                 Age  Annual Income  Spending Score
# count  15079.000000   15079.000000    15079.000000
# mean      54.191591  109742.880562       50.591617
# std       21.119207   52249.425866       28.726977
# min       18.000000   20022.000000        1.000000
# 25%       36.000000   64141.000000       26.000000
# 50%       54.000000  109190.000000       51.000000
# 75%       72.000000  155008.000000       75.000000
# max       90.000000  199974.000000      100.000000

# %% [markdown]
# ## Step 7: Missing Value Analysis
#
# Missing values can negatively affect analytical results.
#
# This step verifies data completeness before proceeding to cleaning and analysis.

# %%
# Checking Missing Values

df.isnull().sum()
# Out:
# Customer ID       0
# Age               0
# Gender            0
# Annual Income     0
# Spending Score    0
# dtype: int64

# %% [markdown]
# ## Step 8: Duplicate Record Check
#
# Duplicate entries may distort customer analysis and segmentation results.
#
# This step ensures each customer record is unique.

# %%
# Checking Duplicate Values

df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Step 9: Column Name Standardization
#
# Column names are standardized to improve readability, maintain consistency, and simplify analytical workflows.

# %%
# Standardize Column Names

df.columns

df = df.rename(columns={
    'Customer ID': 'customer_id',
    'Age': 'age',
    'Gender': 'gender',
    'Annual Income': 'annual_income',
    'Spending Score': 'spending_score'
})

df.head(3)
# Out:
#                             customer_id  age  gender  annual_income  \
# 0  d410ea53-6661-42a9-ad3a-f554b05fd2a7   30    Male         151479
# 1  1770b26f-493f-46b6-837f-4237fb5a314e   58  Female         185088
# 2  e81aa8eb-1767-4b77-87ce-1620dc732c5e   62  Female          70912
#
#    spending_score
# 0              89
# 1              95
# 2              76

# %% [markdown]
# ### Step 10: Data Type Optimization
#
# Categorical variables are converted into appropriate formats to improve memory efficiency and analytical performance.

# %%
# Converting categories for optimization

df['gender'] = df['gender'].astype('category')

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15079 entries, 0 to 15078
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     15079 non-null  str
#  1   age             15079 non-null  int64
#  2   gender          15079 non-null  category
#  3   annual_income   15079 non-null  int64
#  4   spending_score  15079 non-null  int64
# dtypes: category(1), int64(3), str(1)
# memory usage: 486.1 KB

# %% [markdown]
# ### Step 11: Numerical Value Validation
#
# Numerical variables are validated to ensure values fall within realistic business ranges and contain no anomalies.

# %%
# Checking anomalies in Numerical Columns

df[['age', 'annual_income', 'spending_score']].describe().round(2)
# Out:
#             age  annual_income  spending_score
# count  15079.00       15079.00        15079.00
# mean      54.19      109742.88           50.59
# std       21.12       52249.43           28.73
# min       18.00       20022.00            1.00
# 25%       36.00       64141.00           26.00
# 50%       54.00      109190.00           51.00
# 75%       72.00      155008.00           75.00
# max       90.00      199974.00          100.00

# %% [markdown]
# ### Data Cleaning Summary
#
# The dataset was reviewed and cleaned to ensure consistency, reliability, and readiness for analytical processing.
#
# ---
# #### Dataset Structure
# - The dataset contains **15,079 customer records** and **5 variables**.
# - Column names were standardized to maintain consistency and improve analytical readability.
# ---
# #### Data Type Validation
# - Numerical variables (`age`, `annual_income`, `spending_score`) are correctly formatted for statistical analysis.
# - The `gender` variable was converted to a categorical datatype to improve memory efficiency and analytical performance.
# - `customer_id` is retained as a unique identifier for each customer.
# ---
# #### Missing Values Assessment
# - No missing or null values were identified across any column.
# - The dataset is complete and does not require data imputation.
# ---
# #### Duplicate Record Validation
# - No duplicate customer entries were detected.
# - Each record represents a unique customer observation.
# ---
# #### Numerical Value Validation
# - Age ranges between **18 and 90 years**, representing a wide demographic distribution.
# - Annual income ranges from **20,022 to 199,974**, indicating diverse income groups.
# - Spending score ranges from **1 to 100**, making the dataset suitable for behavioral segmentation.
# ---
# #### Conclusion
# The dataset has been successfully cleaned and validated. It is now ready for customer analysis, segmentation, and business insight generation.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Part 2: Customer Analysis
#
# This section analyzes customer demographics, income levels, and spending behaviour to identify meaningful business insights that support customer segmentation and marketing decisions.

# %% [markdown]
# ### 1. What is the average age of customers?
#
# The average customer age provides insight into the dominant demographic group visiting the shopping mall.

# %%
# Average Age of Customers

df['age'].mean().__round__()
print(f"Average Age: {df['age'].mean().__round__()} years")
# Out:
# Average Age: 54 years

# %% [markdown]
# **Result:**
# The average customer age is **54 years**.
#
# **Business Insight:**
# The customer base is primarily composed of middle-aged individuals. This indicates a mature consumer segment likely possessing stable income levels and consistent purchasing behavior. Businesses may focus on lifestyle, wellness, household, and premium convenience offerings that appeal to this demographic.

# %% [markdown]
# ### 2. What is the average annual income of customers?
#
# Understanding customer income levels helps assess purchasing power and pricing strategy suitability.

# %%
# Average Annual Income of Customers

df['annual_income'].mean().__round__(2)
# Out:
# np.float64(109742.88)

# %% [markdown]
# **Result:**
# The average annual income of customers is approximately **109,743**.
#
# **Business Insight:**
# The relatively high average income suggests that the mall attracts financially capable consumers. This presents opportunities for premium product positioning, upselling strategies, and value-added services targeting customers with strong purchasing capacity.

# %% [markdown]
# ### 3. Which gender spends more on average?
#
# Spending behaviour is compared across genders to understand purchasing differences.

# %%
# Average Spending Score of Customers

df.groupby('gender')['spending_score'].mean().round(2)
# Out:
# gender
# Female    50.40
# Male      50.78
# Name: spending_score, dtype: float64

# %%
# Visualize Average Spending Score by Gender

df.groupby('gender')['spending_score'].mean().plot(kind='bar')
plt.title("Average Spending Score by Gender")
plt.xlabel("Gender")
plt.ylabel("Average Spending Score")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **Result:**
# - Female average spending score: **50.40**
# - Male average spending score: **50.78**
#
# **Business Insight:**
# Male customers exhibit a slightly higher average spending score; however, the difference between genders is minimal. This indicates that spending behaviour is relatively balanced across genders, suggesting marketing campaigns should remain broadly inclusive rather than heavily gender-specific.

# %% [markdown]
# ### 4. Which age group has the highest spending score?
#
# Customers are grouped into age categories to identify the most valuable spending demographic.

# %%
# Annual Income vs Spending Score

df['age_group'] = pd.cut(
    df['age'],
    bins=[18,25,35,45,55,65,75,90],
    labels=['18-25','26-35','36-45','46-55','56-65','66-75','76-90'],
    include_lowest=True
)

# %%
# Average Spending Score by Age Group

df.groupby('age_group')['spending_score'].mean().round(2)
# Out:
# age_group
# 18-25    51.84
# 26-35    49.80
# 36-45    50.62
# 46-55    51.08
# 56-65    50.71
# 66-75    50.40
# 76-90    50.19
# Name: spending_score, dtype: float64

# %%
# Visualize Average Spending Score by Age Group

df.groupby('age_group')['spending_score'].mean().plot(kind='bar')
plt.title("Average Spending Score by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Average Spending Score")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **Result:**
# The **18–25 age group** shows the highest average spending score (**51.84**).
#
# **Business Insight:**
# Younger customers demonstrate the strongest spending engagement despite not necessarily having the highest income levels. This suggests higher impulsive buying behaviour and responsiveness to trends, promotions, and experiential retail strategies.
#
# Targeted initiatives such as:
# - digital marketing campaigns,
# - fashion and lifestyle promotions,
# - loyalty rewards,
# can effectively leverage this high-engagement segment.

# %% [markdown]
# ### 5. Is there a relationship between annual income and spending score?
#
# Analyzing the relationship between income and spending behaviour helps determine whether higher income customers necessarily spend more.

# %%
# Visualize Annual Income vs Spending Score

plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='annual_income', y='spending_score')
plt.title("Annual Income vs Spending Score")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.show()

# %%
# Correlation Analysis

df[['annual_income','spending_score']].corr().round(3)
# Out:
#                 annual_income  spending_score
# annual_income           1.000           0.003
# spending_score          0.003           1.000

# %% [markdown]
# **Result:**
# Correlation between annual income and spending score = **0.003**.
#
# **Business Insight:**
# The correlation value is extremely close to zero, indicating **no meaningful relationship** between income and spending behaviour.
#
# This implies:
# - High-income customers do not necessarily spend more.
# - Spending behaviour is driven more by lifestyle preferences, engagement, or psychological factors rather than income alone.
#
# Therefore, customer segmentation should rely on behavioural metrics rather than income level alone.

# %% [markdown]
# ### Customer Analysis Summary
#
# The analysis reveals that customer spending behaviour varies more by age and engagement patterns than by income or gender differences.
#
# Key observations include:
# - A mature overall customer base with strong purchasing capacity.
# - Balanced spending behaviour across genders.
# - Younger customers demonstrating the highest spending engagement.
# - Minimal relationship between income and spending behaviour.
#
# These findings highlight the need for behavioural customer segmentation, which will be performed in the next section.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Part 3: Customer Segmentation
#
# Customer segmentation groups customers based on income levels and spending behaviour.
#
# Segmentation enables businesses to:
# - identify high-value customers,
# - personalize marketing strategies,
# - improve customer retention,
# - optimize revenue generation.

# %% [markdown]
# ### Step 1: Define Income and Spending Thresholds
#
# Customers are categorized as High or Low based on the average annual income and spending score values.
#
# | Income | Spending | Segment             |
# | ------ | -------- | ------------------- |
# | High   | High     | Premium Customers   |
# | High   | Low      | Potential Customers |
# | Low    | High     | Loyal Customers     |
# | Low    | Low      | Budget Customers    |

# %%
# Define thresholds for segmentation

income_threshold = df['annual_income'].mean().round(2)
spending_threshold = df['spending_score'].mean().round(2)

income_threshold, spending_threshold
# Out:
# (np.float64(109742.88), np.float64(50.59))

# %% [markdown]
# ### Step 2: Create Customer Segments
#
# Customers are assigned to segments based on income level and spending behaviour.

# %%
# Define segmentation function

def segment_customer(row):
    if row['annual_income'] >= income_threshold and row['spending_score'] >= spending_threshold:
        return 'High Income - High Spending'
    elif row['annual_income'] >= income_threshold and row['spending_score'] < spending_threshold:
        return 'High Income - Low Spending'
    elif row['annual_income'] < income_threshold and row['spending_score'] >= spending_threshold:
        return 'Low Income - High Spending'
    else:
        return 'Low Income - Low Spending'

df['segment'] = df.apply(segment_customer, axis=1)

df.head(3)
# Out:
#                             customer_id  age  gender  annual_income  \
# 0  d410ea53-6661-42a9-ad3a-f554b05fd2a7   30    Male         151479
# 1  1770b26f-493f-46b6-837f-4237fb5a314e   58  Female         185088
# 2  e81aa8eb-1767-4b77-87ce-1620dc732c5e   62  Female          70912
#
#    spending_score age_group                      segment
# 0              89     26-35  High Income - High Spending
# 1              95     56-65  High Income - High Spending
# 2              76     56-65   Low Income - High Spending

# %% [markdown]
# ### Step 3: Segment Distribution Analysis
#
# The number of customers in each segment is analyzed to understand customer composition.

# %%
# Analyze Segment Distribution

segment_counts = df['segment'].value_counts()
segment_counts
# Out:
# segment
# Low Income - Low Spending      3824
# High Income - High Spending    3799
# Low Income - High Spending     3769
# High Income - Low Spending     3687
# Name: count, dtype: int64

# %%
# Visualize Segment Distribution

segment_counts.plot(kind='barh')
plt.title("Customer Segment Distribution")
plt.xlabel("Segment")
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# ### Step 4: Segment Characteristics
#
# Average income and spending behaviour are examined for each customer segment.

# %%
# Analyze Average Annual Income, Spending Score, and Age by Segment

df.groupby('segment')[['annual_income','spending_score','age']].mean().round()
# Out:
#                              annual_income  spending_score   age
# segment
# High Income - High Spending       155050.0            75.0  54.0
# High Income - Low Spending        155784.0            26.0  54.0
# Low Income - High Spending         64737.0            75.0  54.0
# Low Income - Low Spending          64700.0            26.0  54.0

# %% [markdown]
# ### Step 5 — Segmentation Visualization
#
# Income vs Spending Segmentation Visualization

# %%
# Visualize Annual Income vs Spending Score by Segment

plt.figure(figsize=(8,6))

sns.scatterplot(
    data=df,
    x='annual_income',
    y='spending_score',
    hue='segment'
)

plt.title("Customer Segmentation Based on Income and Spending")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.show()

# %% [markdown]
# ### Advanced Segmentation using K-Means Clustering
#
# K-Means clustering is applied to identify natural customer groupings based on behavioural similarity.

# %%
# Clustering Analysis using K-Means

X = df[['annual_income','spending_score']]

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=4, random_state=42)
df['cluster'] = kmeans.fit_predict(X_scaled)

# %%
# # Map cluster labels to segment names

cluster_map = {
    0: "Low Income - Low Spending",
    1: "High Income - High Spending",
    2: "High Income - Low Spending",
    3: "Low Income - High Spending"
}

df['segment'] = df['cluster'].map(cluster_map)

# %%
# Visualize K-Means Clusters

plt.figure(figsize=(8,6))

sns.scatterplot(
    x=df['annual_income'],
    y=df['spending_score'],
    hue=df['cluster'],
    palette='Set2'
)

# Calculate and plot centroids

centroids_scaled = kmeans.cluster_centers_
centroids = scaler.inverse_transform(centroids_scaled)

plt.scatter(
    centroids[:,0],
    centroids[:,1],
    s=300,
    c='black',
    marker='X',
    label='Centroids'
)

plt.title("K-Means Customer Clusters")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.legend()
plt.show()

# %%
df['cluster'].value_counts()
# Out:
# cluster
# 0    3862
# 1    3788
# 2    3780
# 3    3649
# Name: count, dtype: int64

# %%
df['segment'].value_counts()
# Out:
# segment
# Low Income - Low Spending      3862
# High Income - High Spending    3788
# High Income - Low Spending     3780
# Low Income - High Spending     3649
# Name: count, dtype: int64

# %% [markdown]
# ### Customer Segmentation Summary
#
# Customer segmentation divided customers into four behavioural groups using average income (109,742.88) and average spending score (50.59) as thresholds.
#
# ---
#
# #### 1. High Income – High Spending (Premium Customers)
# - Customers: **3,799**
# - Average Income: ~155,050
# - Average Spending Score: ~75
#
# **Insight:**
# This segment represents the most valuable customers. They possess strong purchasing power and demonstrate high engagement levels. These customers are major revenue contributors and should be prioritized for retention strategies.
#
# **Recommended Actions:**
# - VIP memberships
# - Exclusive product launches
# - Personalized services
# - Loyalty rewards and premium experiences
#
# ---
#
# #### 2. High Income – Low Spending (Potential Customers)
# - Customers: **3,687**
# - Average Income: ~155,784
# - Average Spending Score: ~26
#
# **Insight:**
# Despite having high income levels, these customers show low spending engagement. This indicates untapped revenue potential and possible lack of motivation or targeted marketing.
#
# **Recommended Actions:**
# - Personalized promotions
# - Product recommendations
# - Targeted marketing campaigns
# - Customer engagement programs
#
# ---
#
# #### 3. Low Income – High Spending (Loyal Customers)
# - Customers: **3,769**
# - Average Income: ~64,737
# - Average Spending Score: ~75
#
# **Insight:**
# These customers demonstrate strong shopping engagement despite lower income levels. They are likely value-driven buyers who respond well to promotions and brand loyalty initiatives.
#
# **Recommended Actions:**
# - Discount programs
# - Loyalty points systems
# - Bundle offers
# - Seasonal promotions
#
# ---
#
# #### 4. Low Income – Low Spending (Budget Customers)
# - Customers: **3,824**
# - Average Income: ~64,700
# - Average Spending Score: ~26
#
# **Insight:**
# This segment contributes the least to revenue and exhibits low engagement. Marketing investment should be optimized carefully for this group.
#
# **Recommended Actions:**
# - Mass marketing campaigns
# - Entry-level product offerings
# - Promotional discounts
# - Awareness campaigns
#
# ---
#
# ### Key Segmentation Observation
#
# Customer distribution across all four segments is relatively balanced, indicating diverse customer behaviour within the mall ecosystem.
#
# The analysis confirms that **spending behaviour is not solely dependent on income**, reinforcing the importance of behavioural segmentation for effective marketing strategy.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Part 4: Dashboard / Visualization

# %% [markdown]
# ### Step 1: Data Validation & Quality Checks
#
# Before dashboard development, validation checks were performed to ensure that transformations such as age grouping and customer segmentation were applied correctly without data loss or misclassification.

# %% [markdown]
# Check 1 — Record Count Integrity
#
# Verify no rows disappeared.

# %%
# Check Record Count Integrity

original_rows = len(df)
print("Total Records:", original_rows)
# Out:
# Total Records: 15079

# %% [markdown]
# Check 2 — Age Group Coverage
#
# Make sure every customer belongs to an age group.

# %%
# Check for missing values in 'age_group' column

df['age_group'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Check 3 — Segment Coverage
#
# Ensure segmentation assigned to all customers.

# %%
# Check the distribution of customers across segments

df['segment'].value_counts()
# Out:
# segment
# Low Income - Low Spending      3862
# High Income - High Spending    3788
# High Income - Low Spending     3780
# Low Income - High Spending     3649
# Name: count, dtype: int64

# %% [markdown]
# Check 4 — Dataset Completeness

# %%
# Check for missing values

df.isnull().sum()
# Out:
# customer_id       0
# age               0
# gender            0
# annual_income     0
# spending_score    0
# age_group         0
# segment           0
# cluster           0
# dtype: int64

# %% [markdown]
# Check 5 — Logical Range Validation
#
# Confirm business rules were preserved.

# %%
# Numerical Column Ranges

print("Age Range:", df['age'].min(), "-", df['age'].max())
print("Income Range:", df['annual_income'].min(), "-", df['annual_income'].max())
print("Spending Score Range:", df['spending_score'].min(), "-", df['spending_score'].max())
# Out:
# Age Range: 18 - 90
# Income Range: 20022 - 199974
# Spending Score Range: 1 - 100

# %% [markdown]
# Check 6 — Duplicate Validation

# %%
# Check for duplicate rows

df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Validation Summary
#
# All validation checks confirmed that:
# - no records were lost during preprocessing,
# - all customers were successfully assigned age groups and segments,
# - no missing or duplicate records exist.
#
# The dataset is validated and ready for business dashboard development.

# %% [markdown]
# ## Step 2: Data Export for Dashboard Creation

# %%
# Export Processed Data for Dashboard Creation

df.to_csv("../01 Data/customer segmentation final.csv", index=False)

# %% [markdown]
# ### Exporting Data for Power BI Dashboard
#
# After completing data cleaning, analysis, and customer segmentation, the final processed dataset was exported for dashboard development in Power BI.
#
# This dataset contains:
# - customer demographics
# - income information
# - spending behaviour
# - derived age groups
# - customer segments
#
# The exported file serves as the data source for the interactive business dashboard.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Part 5: Business Recommendations
#
# ### 1. Which segment should the company target most?
#
# The company should primarily target the High Income – High Spending segment.
#
# **Reasoning:**
#
# - Highest purchasing power
# - Strong spending behaviour
# - Highest contribution to revenue generation
#
# **Strategy:**
#
# * VIP memberships
# * Exclusive brand collaborations
# * Personalized marketing campaigns
# * Premium customer experiences
#
# **Business Impact:**
#
# Improves revenue stability and customer lifetime value.
#
# ---
#
# ### 2. What offers can attract low-spending customers?
#
# Low-spending customers can be activated through value-based incentives.
#
# **Recommended Offers:**
#
# * Discount campaigns
# * Loyalty reward points
# * Bundle promotions
# * Seasonal sales events
# * Entry-level product pricing
#
# **Objective:**
#
# Increase purchase frequency and convert occasional visitors into active buyers.
#
# ---
#
# ### 3. How can high-income customers be retained?
#
# Retention should focus on experience rather than discounts.
#
# **Retention Strategies:**
#
# * Personalized recommendations
# * Early access to new collections
# * Premium lounges or services
# * Exclusive events and memberships
# * Data-driven engagement programs
#
# **Expected Outcome:**
#
# Higher retention rates and long-term profitability.
